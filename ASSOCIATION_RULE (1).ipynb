# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=851a916ab74cdc76863f4bf4b44439a97e3e86a6290dda34c3a950054bd9dd9f
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c7ef46ab-276a-451e-b7bb-29a84cfd29af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7ef46ab-276a-451e-b7bb-29a84cfd29af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
online=pd.read_excel('Online retail-ready.xlsx',sheet_name='Sheet1')

# %%
online
# Out:
#                   shrimp    almonds     avocado    vegetables mix  \
# 0                burgers  meatballs        eggs               NaN
# 1                chutney        NaN         NaN               NaN
# 2                 turkey    avocado         NaN               NaN
# 3          mineral water       milk  energy bar  whole wheat rice
# 4         low fat yogurt        NaN         NaN               NaN
# ...                  ...        ...         ...               ...
# 13242         light mayo        NaN         NaN               NaN
# 13243         light mayo        NaN         NaN               NaN
# 13244  frozen vegetables        NaN         NaN               NaN
# 13245          green tea        NaN         NaN               NaN
# 13246    frozen smoothie        NaN         NaN               NaN
#
#       green grapes whole weat flour yams cottage cheese energy drink  \
# 0              NaN              NaN  NaN            NaN          NaN
# ...

# %%
online.stack().value_counts(normalize=True)[:10].plot(kind='bar')
# Out:
# <Axes: >

# %%
online=pd.read_excel('Online retail-ready.xlsx',sheet_name='Sheet1',header=None)

# %%
online
# Out:
#                       0          1           2                 3   \
# 0                 shrimp    almonds     avocado    vegetables mix
# 1                burgers  meatballs        eggs               NaN
# 2                chutney        NaN         NaN               NaN
# 3                 turkey    avocado         NaN               NaN
# 4          mineral water       milk  energy bar  whole wheat rice
# ...                  ...        ...         ...               ...
# 13243         light mayo        NaN         NaN               NaN
# 13244         light mayo        NaN         NaN               NaN
# 13245  frozen vegetables        NaN         NaN               NaN
# 13246          green tea        NaN         NaN               NaN
# 13247    frozen smoothie        NaN         NaN               NaN
#
#                  4                 5     6               7             8   \
# 0      green grapes  whole weat flour  yams  cottage cheese  energy drink
# ...

# %%
#BASIC INFO OF DATA
online.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13248 entries, 0 to 13247
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13248 non-null  object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 2.0+ MB

# %%
#FINDING NULL VALUE
online.isnull().sum()
# Out:
# 0         0
# 1      7501
# 2      8859
# 3      9903
# 4     10719
# 5     11384
# 6     11879
# 7     12267
# 8     12594
# 9     12853
# 10    12992
# 11    13094
# 12    13161
# 13    13201
# 14    13223
# 15    13240
# 16    13244
# 17    13244
# 18    13245
# 19    13247
# dtype: int64

# %%
# STATISTIC SUMMARY OF DATA
online.describe()
# Out:
#                    0              1              2              3          4   \
# count           13248           5747           4389           3345       2529
# unique            118            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq             1061            484            375            201        153
#
#                   5          6          7          8          9   \
# count           1864       1369        981        654        395
# unique           106        102         98         88         80
# top     french fries  green tea  green tea  green tea  green tea
# freq             107         96         67         57         31
#
#                     10         11         12         13         14      15  \
# count              256        154         87         47         25       8
# unique              66         50         43         28         19       8
# ...

# %% [markdown]
# # **Apriori Algorithm**

# %%
transactions=[]
for i in range(0,7501):
  transactions.append([str(online.values[i,j]) for j in range(0,20)])

# %%
online.head(5)
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
online.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13248 entries, 0 to 13247
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13248 non-null  object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 2.0+ MB

# %%
from apyori import apriori

# %%
rules=apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %%
rules
# Out:
# <generator object apriori at 0x7b5890796810>

# %% [markdown]
# # **Visualising the results**
# # Displaying the first results coming directly from the output of the apriori function

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %% [markdown]
# # **Putting the results well organised into a Pandas DataFrame**

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %% [markdown]
# # **Displaying the results sorted by descending lifts**

# %%
df=resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
df
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 8                 pasta          shrimp  0.005066    0.322034  4.506672
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 6           light cream       olive oil  0.003200    0.205128  3.114710

# %%
sns.pairplot(data=df)

# %%
sns.scatterplot(x=df['Support'],y=df['Confidence'])
# Out:
# <Axes: xlabel='Support', ylabel='Confidence'>

# %%
# visualization of obtained rule
df[['Support','Confidence']].hist()
# Out:
# array([[<Axes: title={'center': 'Support'}>,
#         <Axes: title={'center': 'Confidence'}>]], dtype=object)

# %%
df[['Support','Confidence','Lift']].hist()
# Out:
# array([[<Axes: title={'center': 'Support'}>,
#         <Axes: title={'center': 'Confidence'}>],
#        [<Axes: title={'center': 'Lift'}>, <Axes: >]], dtype=object)
